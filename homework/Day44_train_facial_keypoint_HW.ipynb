# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
 # %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
 import tensorflow as tf
 print(tf.__version__)

 import os
 from google.colab import drive 
 drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
 # %cd 'gdrive/My Drive'
 os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
 # %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 1.15.0
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive'
# /content/gdrive/My Drive
# [Errno 2] No such file or directory: 'cupoy_cv_part4 # 可以自己改路徑'
# /content/gdrive/My Drive

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0091 - val_loss: 0.0027
#
# Epoch 00001: val_loss improved from inf to 0.00271, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0023 - val_loss: 0.0021
#
# Epoch 00002: val_loss improved from 0.00271 to 0.00211, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00211 to 0.00191, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00191 to 0.00190, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00190 to 0.00186, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss improved from 0.00186 to 0.00186, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4733e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00186 to 0.00165, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.0285e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00165 to 0.00152, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.2261e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00152 to 0.00140, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.3618e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00140 to 0.00124, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.8519e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00124 to 0.00119, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.4500e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00119 to 0.00113, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.0238e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00113 to 0.00104, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.7673e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss did not improve from 0.00104
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.4767e-04 - val_loss: 0.0010
#
# Epoch 00015: val_loss improved from 0.00104 to 0.00104, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.2483e-04 - val_loss: 9.5200e-04
#
# Epoch 00016: val_loss improved from 0.00104 to 0.00095, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9412e-04 - val_loss: 9.2868e-04
#
# Epoch 00017: val_loss improved from 0.00095 to 0.00093, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.8195e-04 - val_loss: 9.3147e-04
#
# Epoch 00018: val_loss did not improve from 0.00093
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7218e-04 - val_loss: 9.3597e-04
#
# Epoch 00019: val_loss did not improve from 0.00093
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4965e-04 - val_loss: 8.8647e-04
#
# Epoch 00020: val_loss improved from 0.00093 to 0.00089, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4506e-04 - val_loss: 8.6348e-04
#
# Epoch 00021: val_loss improved from 0.00089 to 0.00086, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2923e-04 - val_loss: 8.8905e-04
#
# Epoch 00022: val_loss did not improve from 0.00086
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1612e-04 - val_loss: 8.4289e-04
#
# Epoch 00023: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1841e-04 - val_loss: 8.6020e-04
#
# Epoch 00024: val_loss did not improve from 0.00084
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0489e-04 - val_loss: 8.2047e-04
#
# Epoch 00025: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9535e-04 - val_loss: 8.2889e-04
#
# Epoch 00026: val_loss did not improve from 0.00082
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8319e-04 - val_loss: 8.1504e-04
#
# Epoch 00027: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8027e-04 - val_loss: 8.1136e-04
#
# Epoch 00028: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6611e-04 - val_loss: 7.9756e-04
#
# Epoch 00029: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6818e-04 - val_loss: 8.2287e-04
#
# Epoch 00030: val_loss did not improve from 0.00080
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5474e-04 - val_loss: 7.9514e-04
#
# Epoch 00031: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6111e-04 - val_loss: 8.6946e-04
#
# Epoch 00032: val_loss did not improve from 0.00080
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5374e-04 - val_loss: 8.2296e-04
#
# Epoch 00033: val_loss did not improve from 0.00080
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5063e-04 - val_loss: 8.2690e-04
#
# Epoch 00034: val_loss did not improve from 0.00080
# Epoch 35/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3841e-04 - val_loss: 7.8858e-04
#
# Epoch 00035: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3172e-04 - val_loss: 7.9171e-04
#
# Epoch 00036: val_loss did not improve from 0.00079
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3153e-04 - val_loss: 7.7519e-04
#
# Epoch 00037: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3101e-04 - val_loss: 7.5340e-04
#
# Epoch 00038: val_loss improved from 0.00078 to 0.00075, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2149e-04 - val_loss: 7.8556e-04
#
# Epoch 00039: val_loss did not improve from 0.00075
# Epoch 40/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1756e-04 - val_loss: 7.6215e-04
#
# Epoch 00040: val_loss did not improve from 0.00075
# Epoch 41/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1834e-04 - val_loss: 7.9954e-04
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0610e-04 - val_loss: 7.5464e-04
#
# Epoch 00042: val_loss did not improve from 0.00075
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1528e-04 - val_loss: 8.1313e-04
#
# Epoch 00043: val_loss did not improve from 0.00075
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1089e-04 - val_loss: 7.8369e-04
#
# Epoch 00044: val_loss did not improve from 0.00075
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0905e-04 - val_loss: 7.5932e-04
#
# Epoch 00045: val_loss did not improve from 0.00075
# Epoch 46/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0097e-04 - val_loss: 7.7181e-04
#
# Epoch 00046: val_loss did not improve from 0.00075
# Epoch 47/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0208e-04 - val_loss: 7.7635e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9946e-04 - val_loss: 7.5770e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9609e-04 - val_loss: 8.0295e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9165e-04 - val_loss: 7.4886e-04
#
# Epoch 00050: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9007e-04 - val_loss: 7.6083e-04
#
# Epoch 00051: val_loss did not improve from 0.00075
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9095e-04 - val_loss: 7.4589e-04
#
# Epoch 00052: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8470e-04 - val_loss: 7.6592e-04
#
# Epoch 00053: val_loss did not improve from 0.00075
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8160e-04 - val_loss: 7.6292e-04
#
# Epoch 00054: val_loss did not improve from 0.00075
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8266e-04 - val_loss: 7.7678e-04
#
# Epoch 00055: val_loss did not improve from 0.00075
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7758e-04 - val_loss: 7.5506e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7907e-04 - val_loss: 7.6036e-04
#
# Epoch 00057: val_loss did not improve from 0.00075
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7213e-04 - val_loss: 7.4996e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7243e-04 - val_loss: 7.5068e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7070e-04 - val_loss: 7.6314e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7138e-04 - val_loss: 7.7210e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6885e-04 - val_loss: 7.4812e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7028e-04 - val_loss: 7.6311e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6599e-04 - val_loss: 7.4806e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6014e-04 - val_loss: 7.8349e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5583e-04 - val_loss: 7.5862e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5755e-04 - val_loss: 7.4628e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5699e-04 - val_loss: 7.5691e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5129e-04 - val_loss: 7.4790e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5465e-04 - val_loss: 7.5174e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5202e-04 - val_loss: 7.5516e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4750e-04 - val_loss: 7.8002e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4906e-04 - val_loss: 7.6888e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4321e-04 - val_loss: 7.6091e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4486e-04 - val_loss: 7.6808e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4529e-04 - val_loss: 7.6767e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4332e-04 - val_loss: 7.3483e-04
#
# Epoch 00077: val_loss improved from 0.00075 to 0.00073, saving model to best_weights.h5
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3984e-04 - val_loss: 7.6747e-04
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4348e-04 - val_loss: 7.7951e-04
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3926e-04 - val_loss: 7.5796e-04
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3636e-04 - val_loss: 7.6435e-04
#
# Epoch 00081: val_loss did not improve from 0.00073
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3558e-04 - val_loss: 7.6044e-04
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3766e-04 - val_loss: 7.7995e-04
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3631e-04 - val_loss: 7.4313e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3329e-04 - val_loss: 7.3990e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3574e-04 - val_loss: 7.2130e-04
#
# Epoch 00086: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4027e-04 - val_loss: 7.3070e-04
#
# Epoch 00087: val_loss did not improve from 0.00072
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3975e-04 - val_loss: 7.3015e-04
#
# Epoch 00088: val_loss did not improve from 0.00072
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3145e-04 - val_loss: 7.5783e-04
#
# Epoch 00089: val_loss did not improve from 0.00072
# Epoch 90/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3137e-04 - val_loss: 7.4986e-04
#
# Epoch 00090: val_loss did not improve from 0.00072
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3033e-04 - val_loss: 7.6982e-04
#
# Epoch 00091: val_loss did not improve from 0.00072
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2698e-04 - val_loss: 7.6931e-04
#
# Epoch 00092: val_loss did not improve from 0.00072
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2728e-04 - val_loss: 7.5320e-04
#
# Epoch 00093: val_loss did not improve from 0.00072
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2340e-04 - val_loss: 7.5365e-04
#
# Epoch 00094: val_loss did not improve from 0.00072
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2214e-04 - val_loss: 7.6792e-04
#
# Epoch 00095: val_loss did not improve from 0.00072
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2146e-04 - val_loss: 7.7773e-04
#
# Epoch 00096: val_loss did not improve from 0.00072
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2840e-04 - val_loss: 7.3020e-04
#
# Epoch 00097: val_loss did not improve from 0.00072
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3378e-04 - val_loss: 7.8052e-04
#
# Epoch 00098: val_loss did not improve from 0.00072
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3993e-04 - val_loss: 7.5251e-04
#
# Epoch 00099: val_loss did not improve from 0.00072
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2941e-04 - val_loss: 7.7910e-04
#
# Epoch 00100: val_loss did not improve from 0.00072
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2277e-04 - val_loss: 7.6267e-04
#
# Epoch 00101: val_loss did not improve from 0.00072
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1993e-04 - val_loss: 7.5242e-04
#
# Epoch 00102: val_loss did not improve from 0.00072
# Epoch 103/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2083e-04 - val_loss: 7.8380e-04
#
# Epoch 00103: val_loss did not improve from 0.00072
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1765e-04 - val_loss: 7.3761e-04
#
# Epoch 00104: val_loss did not improve from 0.00072
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1459e-04 - val_loss: 7.6878e-04
#
# Epoch 00105: val_loss did not improve from 0.00072
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1908e-04 - val_loss: 7.7857e-04
#
# Epoch 00106: val_loss did not improve from 0.00072
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1799e-04 - val_loss: 7.5845e-04
#
# Epoch 00107: val_loss did not improve from 0.00072
# Epoch 108/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1895e-04 - val_loss: 7.6244e-04
#
# Epoch 00108: val_loss did not improve from 0.00072
# Epoch 109/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1386e-04 - val_loss: 7.7042e-04
#
# Epoch 00109: val_loss did not improve from 0.00072
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0934e-04 - val_loss: 7.5090e-04
#
# Epoch 00110: val_loss did not improve from 0.00072
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0802e-04 - val_loss: 7.3713e-04
#
# Epoch 00111: val_loss did not improve from 0.00072
# Epoch 112/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1119e-04 - val_loss: 7.5962e-04
#
# Epoch 00112: val_loss did not improve from 0.00072
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1021e-04 - val_loss: 7.2771e-04
#
# Epoch 00113: val_loss did not improve from 0.00072
# Epoch 114/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0790e-04 - val_loss: 7.4660e-04
#
# Epoch 00114: val_loss did not improve from 0.00072
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0688e-04 - val_loss: 7.4827e-04
#
# Epoch 00115: val_loss did not improve from 0.00072
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0728e-04 - val_loss: 7.6465e-04
#
# Epoch 00116: val_loss did not improve from 0.00072
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0988e-04 - val_loss: 7.3762e-04
#
# Epoch 00117: val_loss did not improve from 0.00072
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0765e-04 - val_loss: 7.5584e-04
#
# Epoch 00118: val_loss did not improve from 0.00072
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0420e-04 - val_loss: 7.4833e-04
#
# Epoch 00119: val_loss did not improve from 0.00072
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0565e-04 - val_loss: 7.4375e-04
#
# Epoch 00120: val_loss did not improve from 0.00072
# Epoch 121/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0271e-04 - val_loss: 7.6581e-04
#
# Epoch 00121: val_loss did not improve from 0.00072
# Epoch 122/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0450e-04 - val_loss: 7.8748e-04
#
# Epoch 00122: val_loss did not improve from 0.00072
# Epoch 123/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0721e-04 - val_loss: 7.3016e-04
#
# Epoch 00123: val_loss did not improve from 0.00072
# Epoch 124/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0310e-04 - val_loss: 7.5577e-04
#
# Epoch 00124: val_loss did not improve from 0.00072
# Epoch 125/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0255e-04 - val_loss: 7.6184e-04
#
# Epoch 00125: val_loss did not improve from 0.00072
# Epoch 126/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0021e-04 - val_loss: 7.8927e-04
#
# Epoch 00126: val_loss did not improve from 0.00072
# Epoch 127/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0100e-04 - val_loss: 7.3876e-04
#
# Epoch 00127: val_loss did not improve from 0.00072
# Epoch 128/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9160e-05 - val_loss: 7.5089e-04
#
# Epoch 00128: val_loss did not improve from 0.00072
# Epoch 129/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9757e-05 - val_loss: 7.1222e-04
#
# Epoch 00129: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 130/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5739e-05 - val_loss: 7.3954e-04
#
# Epoch 00130: val_loss did not improve from 0.00071
# Epoch 131/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0025e-04 - val_loss: 7.4397e-04
#
# Epoch 00131: val_loss did not improve from 0.00071
# Epoch 132/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0010e-04 - val_loss: 7.4872e-04
#
# Epoch 00132: val_loss did not improve from 0.00071
# Epoch 133/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6616e-05 - val_loss: 7.8362e-04
#
# Epoch 00133: val_loss did not improve from 0.00071
# Epoch 134/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9303e-05 - val_loss: 7.7575e-04
#
# Epoch 00134: val_loss did not improve from 0.00071
# Epoch 135/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5171e-05 - val_loss: 7.5294e-04
#
# Epoch 00135: val_loss did not improve from 0.00071
# Epoch 136/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6372e-05 - val_loss: 7.6943e-04
#
# Epoch 00136: val_loss did not improve from 0.00071
# Epoch 137/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1633e-05 - val_loss: 7.6192e-04
#
# Epoch 00137: val_loss did not improve from 0.00071
# Epoch 138/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7074e-05 - val_loss: 7.6285e-04
#
# Epoch 00138: val_loss did not improve from 0.00071
# Epoch 139/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7333e-05 - val_loss: 7.8036e-04
#
# Epoch 00139: val_loss did not improve from 0.00071
# Epoch 140/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5067e-05 - val_loss: 7.7192e-04
#
# Epoch 00140: val_loss did not improve from 0.00071
# Epoch 141/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4532e-05 - val_loss: 7.3648e-04
#
# Epoch 00141: val_loss did not improve from 0.00071
# Epoch 142/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2213e-05 - val_loss: 7.5446e-04
#
# Epoch 00142: val_loss did not improve from 0.00071
# Epoch 143/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0093e-05 - val_loss: 7.5988e-04
#
# Epoch 00143: val_loss did not improve from 0.00071
# Epoch 144/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1154e-05 - val_loss: 7.4449e-04
#
# Epoch 00144: val_loss did not improve from 0.00071
# Epoch 145/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1651e-05 - val_loss: 7.2954e-04
#
# Epoch 00145: val_loss did not improve from 0.00071
# Epoch 146/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0863e-05 - val_loss: 7.2747e-04
#
# Epoch 00146: val_loss did not improve from 0.00071
# Epoch 147/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2637e-05 - val_loss: 7.3977e-04
#
# Epoch 00147: val_loss did not improve from 0.00071
# Epoch 148/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2143e-05 - val_loss: 7.4598e-04
#
# Epoch 00148: val_loss did not improve from 0.00071
# Epoch 149/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3517e-05 - val_loss: 7.5339e-04
#
# Epoch 00149: val_loss did not improve from 0.00071
# Epoch 150/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0666e-05 - val_loss: 7.6004e-04
#
# Epoch 00150: val_loss did not improve from 0.00071

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
'''
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
'''


hist_model_aug = model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, nb_epoch = 20, callbacks=[checkpoint, hist], shuffle=True, validation_data=(train_X, points_train))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=66, callbacks=[<keras.ca..., shuffle=True, validation_data=(array([[[..., epochs=20)`
#   # This is added back by InteractiveShellApp.init_path()
# Epoch 1/20
# 66/66 [==============================] - 24s 358ms/step - loss: 0.0042 - val_loss: 0.0011
#
# Epoch 00001: val_loss did not improve from 0.00071
# Epoch 2/20
# 66/66 [==============================] - 23s 347ms/step - loss: 0.0015 - val_loss: 0.0011
#
# Epoch 00002: val_loss did not improve from 0.00071
# Epoch 3/20
# 66/66 [==============================] - 23s 346ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00071
# Epoch 4/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00071
# Epoch 5/20
# 66/66 [==============================] - 23s 348ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00071
# Epoch 6/20
# 66/66 [==============================] - 23s 347ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00071
# Epoch 7/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00071
# Epoch 8/20
# 66/66 [==============================] - 23s 345ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00008: val_loss did not improve from 0.00071
# Epoch 9/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00071
# Epoch 10/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00071
# Epoch 11/20
# 66/66 [==============================] - 23s 345ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00071
# Epoch 12/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00071
# Epoch 13/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00071
# Epoch 14/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00071
# Epoch 15/20
# 66/66 [==============================] - 23s 341ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00071
# Epoch 16/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00071
# Epoch 17/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00071
# Epoch 18/20
# 66/66 [==============================] - 23s 344ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00071
# Epoch 19/20
# 66/66 [==============================] - 23s 346ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00071
# Epoch 20/20
# 66/66 [==============================] - 23s 345ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00071

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
